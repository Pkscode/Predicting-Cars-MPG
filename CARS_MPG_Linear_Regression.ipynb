# %% [markdown]
# # PROBLEM STATEMENT

# %% [markdown]
# ### To predict Miles per Gallon (MPG) of the car dataset with some independent variable

# %%
#Importing Library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline

# %%
#importing and reading data
data=pd.read_csv("C:\\Users\\sahoo\\Desktop\\DATASETS\\cars.csv")

# %%
#pwd
#to check location of dataset

# %%
#to check first 5 records
data.head()
# Out:
#               Model    MPG  Cylinder   Disp     HP  Drat     Wt   Qsec  VS  \
# 0          Mazda RX4  21.0         6  160.0  110.0  3.90  2.620  16.46   0
# 1      Mazda RX4 Wag  21.0         6  160.0  110.0  3.90  2.875  17.02   0
# 2         Datsun 710  22.8         4  108.0   93.0  3.85  2.320  18.61   1
# 3     Hornet 4 Drive  21.4         6  258.0  110.0  3.08  3.215  19.44   1
# 4  Hornet Sportabout  18.7         8  360.0  175.0  3.15  3.440  17.02   0
#
#    AM  Gear  Carb
# 0   1     4     4
# 1   1     4     4
# 2   1     4     1
# 3   0     3     1
# 4   0     3     2

# %%
#to check last 5 tails
data.tail()
# Out:
#             Model    MPG  Cylinder   Disp     HP  Drat     Wt  Qsec  VS  AM  \
# 27    Lotus Europa  30.4         4   95.1  113.0  3.77  1.513  16.9   1   1
# 28  Ford Pantera L  15.8         8  351.0  264.0  4.22  3.170  14.5   0   1
# 29    Ferrari Dino  19.7         6  145.0  175.0  3.62  2.770  15.5   0   1
# 30   Maserati Bora  15.0         8  301.0  335.0  3.54  3.570  14.6   0   1
# 31      Volvo 142E  21.4         4  121.0  109.0  4.11  2.780  18.6   1   1
#
#     Gear  Carb
# 27     5     2
# 28     5     4
# 29     5     6
# 30     5     8
# 31     4     2

# %%
#to check data information
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
# Model       32 non-null object
# MPG         32 non-null float64
# Cylinder    32 non-null int64
# Disp        29 non-null float64
# HP          29 non-null float64
# Drat        32 non-null float64
# Wt          32 non-null float64
# Qsec        32 non-null float64
# VS          32 non-null int64
# AM          32 non-null int64
# Gear        32 non-null int64
# Carb        32 non-null int64
# dtypes: float64(6), int64(5), object(1)
# memory usage: 3.1+ KB

# %%
# to check null values in data set
data.isnull()
# Out:
#     Model     MPG  Cylinder   Disp     HP   Drat     Wt   Qsec     VS     AM  \
# 0    False  False     False  False  False  False  False  False  False  False
# 1    False  False     False  False  False  False  False  False  False  False
# 2    False  False     False  False  False  False  False  False  False  False
# 3    False  False     False  False  False  False  False  False  False  False
# 4    False  False     False  False  False  False  False  False  False  False
# 5    False  False     False  False  False  False  False  False  False  False
# 6    False  False     False  False  False  False  False  False  False  False
# 7    False  False     False  False  False  False  False  False  False  False
# 8    False  False     False  False  False  False  False  False  False  False
# 9    False  False     False   True   True  False  False  False  False  False
# 10   False  False     False  False  False  False  False  False  False  False
# ...

# %%
# to sum up all null values together
data.isnull().sum()
# Out:
# Model       0
# MPG         0
# Cylinder    0
# Disp        3
# HP          3
# Drat        0
# Wt          0
# Qsec        0
# VS          0
# AM          0
# Gear        0
# Carb        0
# dtype: int64

# %%
# filling up the null values
data=data.fillna(data.mean())

# %%
data.boxplot()
plt.show()

# %%
data.corr()
# Out:
#                MPG  Cylinder      Disp        HP      Drat        Wt  \
# MPG       1.000000 -0.852162 -0.844253 -0.764345  0.681172 -0.867659
# Cylinder -0.852162  1.000000  0.883549  0.806028 -0.699938  0.782496
# Disp     -0.844253  0.883549  1.000000  0.781902 -0.682647  0.882466
# HP       -0.764345  0.806028  0.781902  1.000000 -0.414259  0.649502
# Drat      0.681172 -0.699938 -0.682647 -0.414259  1.000000 -0.712441
# Wt       -0.867659  0.782496  0.882466  0.649502 -0.712441  1.000000
# Qsec      0.418684 -0.591242 -0.428585 -0.711671  0.091205 -0.174716
# VS        0.664039 -0.810812 -0.677328 -0.689782  0.440278 -0.554916
# AM        0.599832 -0.522607 -0.589928 -0.227285  0.712711 -0.692495
# Gear      0.480285 -0.492687 -0.530916 -0.091671  0.699610 -0.583287
# Carb     -0.550925  0.526988  0.407567  0.761158 -0.090790  0.427606
#
#               Qsec        VS        AM      Gear      Carb
# MPG       0.418684  0.664039  0.599832  0.480285 -0.550925
# ...

# %%
sb.heatmap(data.corr())

# %%
data.isnull().sum()
# Out:
# Model       0
# MPG         0
# Cylinder    0
# Disp        0
# HP          0
# Drat        0
# Wt          0
# Qsec        0
# VS          0
# AM          0
# Gear        0
# Carb        0
# dtype: int64

# %%
data.describe()
# Out:
#              MPG   Cylinder        Disp          HP       Drat         Wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  229.789655  145.206897   3.596563   3.217250
# std     6.026948   1.785922  122.883520   67.890509   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  227.394828  134.103448   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  176.250000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             Qsec         VS         AM       Gear     Carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %% [markdown]
# ## Preparing data

# %%
X= data.loc[:,["HP", "Wt", "AM"] ]
y= data.MPG

# %%
#bringing module to train our model
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y , test_size=0.20, random_state=0)

# %%
print ("X_train shape", X_train.shape)
print ("X_test shape", X_test.shape)
print ("y_train shape", y_train.shape)
print ("y_test shape", y_test.shape)
# Out:
# X_train shape (25, 3)
# X_test shape (7, 3)
# y_train shape (25,)
# y_test shape (7,)

# %%
#import linear Regression
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
#model is fitted here so it means it is trained now
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_predict=model.predict(X_test)

# %%
# MODEL EVALUATION
from sklearn import metrics
from sklearn.metrics import r2_score, accuracy_score

# %%
r2_score(y_test, y_predict)
# Out:
# 0.11855520653880214

# %%
y_test
# Out:
# 11    16.4
# 22    15.2
# 10    17.8
# 2     22.8
# 16    14.7
# 14    10.4
# 28    15.8
# Name: MPG, dtype: float64

# %%
y_predict
# Out:
# array([14.98776511, 18.54876689, 19.40243082, 26.23330188,  8.16909373,
#         9.3658597 , 17.23091304])

# %%
plt.scatter(y_test, y_predict)

# %% [markdown]
# # Summary

# %%
#importing all libraries
#reading & importing data
#checking null values and fill it up 
#preparing data
#importing train_test_split & shaping our training and test sets
#performing train_test_split with some test_size
#fitting our model  ##ERROR: make sure model is not containing any null values otherwise it will show nan or infinity error
#predicting y with the help of x_test
#importing metrices to use r2_score and accuracy_score
#plt.scatter to visualise the actual values and predicted values
